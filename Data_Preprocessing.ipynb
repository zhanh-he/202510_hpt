# %% [markdown]
# # Pack dataset to hdf5s

# %%
# !python3 pytorch/features.py pack_smd_dataset_to_hdf5 feature.sample_rate=16000
# !python3 pytorch/features.py pack_maestro_dataset_to_hdf5 feature.sample_rate=16000
# !python3 pytorch/features.py pack_maps_dataset_to_hdf5 feature.sample_rate=16000
# Out:
# root        : INFO     Packing SMD dataset: /mnt/d/ipynb/dataset/SMD
# 0: Bach_BWV849-01_001_20090916-SMD
# root        : INFO     Processed Bach_BWV849-01_001_20090916-SMD
# 1: Bach_BWV849-02_001_20090916-SMD
# root        : INFO     Processed Bach_BWV849-02_001_20090916-SMD
# 2: Bach_BWV871-01_002_20090916-SMD
# root        : INFO     Processed Bach_BWV871-01_002_20090916-SMD
# 3: Bach_BWV871-02_002_20090916-SMD
# root        : INFO     Processed Bach_BWV871-02_002_20090916-SMD
# 4: Bach_BWV875-01_002_20090916-SMD
# root        : INFO     Processed Bach_BWV875-01_002_20090916-SMD
# 5: Bach_BWV875-02_002_20090916-SMD
# root        : INFO     Processed Bach_BWV875-02_002_20090916-SMD
# 6: Bach_BWV888-01_008_20110315-SMD
# root        : INFO     Processed Bach_BWV888-01_008_20110315-SMD
# 7: Bach_BWV888-02_008_20110315-SMD
# root        : INFO     Processed Bach_BWV888-02_008_20110315-SMD
# 8: Bartok_SZ080-01_002_20110315-SMD
# root        : INFO     Processed Bartok_SZ080-01_002_20110315-SMD
# 9: Bartok_SZ080-02_002_20110315-SMD
# root        : INFO     Processed Bartok_SZ080-02_002_20110315-SMD
# 10: Bartok_SZ080-03_002_20110315-SMD
# root        : INFO     Processed Bartok_SZ080-03_002_20110315-SMD
# 11: Beethoven_Op027No1-01_003_20090916-SMD
# root        : INFO     Processed Beethoven_Op027No1-01_003_20090916-SMD
# 12: Beethoven_Op027No1-02_003_20090916-SMD
# root        : INFO     Processed Beethoven_Op027No1-02_003_20090916-SMD
# 13: Beethoven_Op027No1-03_003_20090916-SMD
# root        : INFO     Processed Beethoven_Op027No1-03_003_20090916-SMD
# 14: Beethoven_Op031No2-01_002_20090916-SMD
# root        : INFO     Processed Beethoven_Op031No2-01_002_20090916-SMD
# 15: Beethoven_Op031No2-02_002_20090916-SMD
# root        : INFO     Processed Beethoven_Op031No2-02_002_20090916-SMD
# 16: Beethoven_Op031No2-03_002_20090916-SMD
# root        : INFO     Processed Beethoven_Op031No2-03_002_20090916-SMD
# 17: Beethoven_WoO080_001_20081107-SMD
# root        : INFO     Processed Beethoven_WoO080_001_20081107-SMD
# 18: Brahms_Op005-01_002_20110315-SMD
# root        : INFO     Processed Brahms_Op005-01_002_20110315-SMD
# 19: Brahms_Op010No1_003_20090916-SMD
# root        : INFO     Processed Brahms_Op010No1_003_20090916-SMD
# 20: Brahms_Op010No2_003_20090916-SMD
# root        : INFO     Processed Brahms_Op010No2_003_20090916-SMD
# 21: Chopin_Op010-03_007_20100611-SMD
# root        : INFO     Processed Chopin_Op010-03_007_20100611-SMD
# 22: Chopin_Op010-04_007_20100611-SMD
# root        : INFO     Processed Chopin_Op010-04_007_20100611-SMD
# 23: Chopin_Op026No1_003_20100611-SMD
# root        : INFO     Processed Chopin_Op026No1_003_20100611-SMD
# 24: Chopin_Op026No2_005_20100611-SMD
# root        : INFO     Processed Chopin_Op026No2_005_20100611-SMD
# 25: Chopin_Op028-01_003_20100611-SMD
# root        : INFO     Processed Chopin_Op028-01_003_20100611-SMD
# 26: Chopin_Op028-03_003_20100611-SMD
# root        : INFO     Processed Chopin_Op028-03_003_20100611-SMD
# 27: Chopin_Op028-04_003_20100611-SMD
# root        : INFO     Processed Chopin_Op028-04_003_20100611-SMD
# 28: Chopin_Op028-11_003_20100611-SMD
# root        : INFO     Processed Chopin_Op028-11_003_20100611-SMD
# 29: Chopin_Op028-15_006_20100611-SMD
# root        : INFO     Processed Chopin_Op028-15_006_20100611-SMD
# 30: Chopin_Op028-17_005_20100611-SMD
# root        : INFO     Processed Chopin_Op028-17_005_20100611-SMD
# 31: Chopin_Op029_004_20100611-SMD
# root        : INFO     Processed Chopin_Op029_004_20100611-SMD
# 32: Chopin_Op048No1_007_20100611-SMD
# root        : INFO     Processed Chopin_Op048No1_007_20100611-SMD
# 33: Chopin_Op066_006_20100611-SMD
# root        : INFO     Processed Chopin_Op066_006_20100611-SMD
# 34: Haydn_Hob017No4_003_20090916-SMD
# root        : INFO     Processed Haydn_Hob017No4_003_20090916-SMD
# 35: Haydn_HobXVINo52-01_008_20110315-SMD
# root        : INFO     Processed Haydn_HobXVINo52-01_008_20110315-SMD
# 36: Haydn_HobXVINo52-02_008_20110315-SMD
# root        : INFO     Processed Haydn_HobXVINo52-02_008_20110315-SMD
# 37: Haydn_HobXVINo52-03_008_20110315-SMD
# root        : INFO     Processed Haydn_HobXVINo52-03_008_20110315-SMD
# 38: Liszt_AnnesDePelerinage-LectureDante_002_20090916-SMD
# root        : INFO     Processed Liszt_AnnesDePelerinage-LectureDante_002_20090916-SMD
# 39: Liszt_KonzertetuedeNo2LaLeggierezza_003_20090916-SMD
# root        : INFO     Processed Liszt_KonzertetuedeNo2LaLeggierezza_003_20090916-SMD
# 40: Liszt_VariationenBachmotivWeinenKlagenSorgenZagen_001_20090916-SMD
# root        : INFO     Processed Liszt_VariationenBachmotivWeinenKlagenSorgenZagen_001_20090916-SMD
# 41: Mozart_KV265_006_20110315-SMD
# root        : INFO     Processed Mozart_KV265_006_20110315-SMD
# 42: Mozart_KV398_002_20110315-SMD
# root        : INFO     Processed Mozart_KV398_002_20110315-SMD
# 43: Rachmaninoff_Op036-01_007_20110315-SMD
# root        : INFO     Processed Rachmaninoff_Op036-01_007_20110315-SMD
# 44: Rachmaninoff_Op036-02_007_20110315-SMD
# root        : INFO     Processed Rachmaninoff_Op036-02_007_20110315-SMD
# 45: Rachmaninoff_Op036-03_007_20110315-SMD
# root        : INFO     Processed Rachmaninoff_Op036-03_007_20110315-SMD
# 46: Rachmaninov_Op039No1_002_20090916-SMD
# root        : INFO     Processed Rachmaninov_Op039No1_002_20090916-SMD
# 47: Ravel_JeuxDEau_008_20110315-SMD
# root        : INFO     Processed Ravel_JeuxDEau_008_20110315-SMD
# 48: Ravel_ValsesNoblesEtSentimentales_003_20090916-SMD
# root        : INFO     Processed Ravel_ValsesNoblesEtSentimentales_003_20090916-SMD
# 49: Skryabin_Op008No8_003_20090916-SMD
# root        : INFO     Processed Skryabin_Op008No8_003_20090916-SMD
# root        : INFO     Write HDF5 to ./workspaces/hdf5s/smd
# root        : INFO     Total files processed: 50
# root        : INFO     Time taken: 427.778 s

# %% [markdown]
# # Analyse Dataset Attributes

# %%
import h5py

file_path = "./workspaces/hdf5s/smd/Bach_BWV849-01_001_20090916-SMD.h5"

with h5py.File(file_path, 'r') as hf:
    # List all attributes
    print("SMD Attributes:", list(hf.attrs.keys()))

    # Access the 'duration' attribute
    duration = hf.attrs['duration']
    print("Duration:", duration)

    # Access the 'duration' attribute
    midi_filename = hf.attrs['midi_filename']
    print("MIDI:", midi_filename)

    # Access the 'duration' attribute
    audio_filename = hf.attrs['audio_filename']
    print("Audio:", audio_filename)

    # Access the 'duration' attribute
    split = hf.attrs['split']
    print("Split:", split)
# Out:
# SMD Attributes: ['audio_filename', 'duration', 'midi_filename', 'split']
# Duration: 157.0
# MIDI: b'Bach_BWV849-01_001_20090916-SMD.mid'
# Audio: b'Bach_BWV849-01_001_20090916-SMD.wav'
# Split: b'test'

# %%
import h5py

file_path = "./workspaces/hdf5s/maestro/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.h5"

with h5py.File(file_path, 'r') as hf:
    # List all attributes
    print("Maestro Attributes:", list(hf.attrs.keys()))

    # Access the 'duration' attribute
    duration = hf.attrs['duration']
    print("Duration:", duration)

    # Access the 'duration' attribute
    midi_filename = hf.attrs['midi_filename']
    print("MIDI:", midi_filename)

    # Access the 'duration' attribute
    audio_filename = hf.attrs['audio_filename']
    print("Audio:", audio_filename)

    # Access the 'duration' attribute
    split = hf.attrs['split']
    print("Split:", split)
# Out:
# Maestro Attributes: ['audio_filename', 'canonical_composer', 'canonical_title', 'duration', 'midi_filename', 'split', 'year']
# Duration: 968.2568
# MIDI: b'2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi'
# Audio: b'2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.wav'
# Split: b'train'

# %%
import h5py

file_path = "./workspaces/hdf5s/maps/MAPS_MUS-bk_xmas1_ENSTDkAm.h5"

with h5py.File(file_path, 'r') as hf:
    # List all attributes
    print("MAPS Attributes:", list(hf.attrs.keys()))

    # Access the 'duration' attribute
    duration = hf.attrs['duration']
    print("Duration:", duration)

    # Access the 'duration' attribute
    midi_filename = hf.attrs['midi_filename']
    print("MIDI:", midi_filename)

    # Access the 'duration' attribute
    audio_filename = hf.attrs['audio_filename']
    print("Audio:", audio_filename)

    # Access the 'duration' attribute
    split = hf.attrs['split']
    print("Split:", split)
# Out:
# MAPS Attributes: ['audio_filename', 'duration', 'midi_filename', 'split']
# Duration: 385.432
# MIDI: b'MAPS_MUS-bk_xmas1_ENSTDkAm.mid'
# Audio: b'MAPS_MUS-bk_xmas1_ENSTDkAm.wav'
# Split: b'test'

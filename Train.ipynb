# %% [markdown]
# # Train
# The default training parameters are defined in the **pytorch/config.yaml**

# %% [markdown]
# SPLab 12 vCPU ---> num_workers=12\
# Alien 20 vCPU ---> num_workers=8 (at most coz GPU memory)\
# Colab vCPU unknown ---> num_workers=8 (top up cost-efficency)\
# Cloud 12 vCPU ---> num_workers=6 or 8 (intend, as strong GPU handle more data)\

# %% [markdown]
# | Model Name      | Extra Inputs | GPU Memory | 10k Iteration Train Time|
# |-----------------|--------------|------------|-------------------------|
# | CRNN Single     | None         | 12.5G      | 3090:1.4h -- p100:2h    |
# | CRNN Dual       | Onset        | 13.3G      | 3090:1.5h -- p100:2.4h  |
# | CRNN Triple     | Onset & Frame| 13.5G      | 3090:1.5h -- p100:2.4h  |
# | Mamba1 Single   | None         | 13.1G      | in progress & not in paper            |

# %%
# !python pytorch/main_iter.py model.name='Single_Velocity_HPT'
# !python pytorch/main_iter.py model.name='Dual_Velocity_HPT' model.input2='onset'
# !python pytorch/main_iter.py model.name='Dual_Velocity_HPT' model.input2='frame'
# !python pytorch/main_iter.py model.name='Dual_Velocity_HPT' model.input2='exframe'
# !python pytorch/main_iter.py model.name='Triple_Velocity_HPT' model.input2='onset' model.input3='frame'
# !python pytorch/main_iter.py model.name='Triple_Velocity_HPT' model.input2='onset' model.input3='exframe'
# !python pytorch/main_iter.py model.name='Triple_Velocity_HPT' model.input2='frame' model.input3='exframe'

# %%
# !python pytorch/main_iter.py model.name='Single_Velocity_HPT'
# Out:
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/einops/_torch_specific.py:109: ImportWarning: allow_ops_in_compiled_graph failed to import torch: ensure pytorch >=2.0
#   warnings.warn("allow_ops_in_compiled_graph failed to import torch: ensure pytorch >=2.0", ImportWarning)
# root        : INFO     {'wandb': {'project': '202510_hpt', 'name': '${model.name}-ext${model.input2}${model.input3}-iter${exp.total_iteration}-lr${exp.learning_rate}-decay${exp.decay}${exp.reduce_iteration}-seed${exp.random_seed}'}, 'exp': {'workspace': '/media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces', 'resume_iteration': 0, 'total_iteration': 200000, 'save_iteration': 5000, 'eval_iteration': 5000, 'learning_rate': 0.0001, 'optim': 'adam', 'decay': True, 'reduce_iteration': 10000, 'loss_type': 'velocity_bce', 'random_seed': 86, 'mini_data': False, 'cuda': True, 'debug': False, 'num_workers': 12, 'batch_size': 12, 'run_infer': 'single', 'ckpt_iteration': ''}, 'feature': {'audio_feature': 'logmel', 'classes_num': 88, 'segment_seconds': 10.0, 'hop_seconds': 1.0, 'sample_rate': 1600, 'fft_size': 2048, 'frames_per_second': 100, 'augmentor': None, 'begin_note': 21, 'velocity_scale': 128, 'max_note_shift': 0}, 'dataset': {'train_set': 'maestro', 'test_set': 'smd', 'train_h5': '${exp.workspace}/hdf5s/${dataset.train_set}', 'test_h5': '${exp.workspace}/hdf5s/${dataset.test_set}', 'smd_dir': '/mnt/d/ipynb/dataset/SMD', 'maestro_dir': '/mnt/d/ipynb/dataset/maestro-v3.0.0', 'maps_dir': '/mnt/d/ipynb/dataset/MAPS_dataset'}, 'model': {'type': 'velo', 'name': 'Single_Velocity_HPT', 'input2': None, 'input3': None}, 'post': {'post_processor_type': 'regression', 'frame_threshold': 0.3, 'onset_threshold': 0.3, 'offset_threshold': 0.3, 'pedal_offset_threshold': 0.2}, 'score': {'evaluate_frame': True, 'evaluate_velocity': True, 'evaluate_pedal': False, 'onset_tolerance': 0.05, 'offset_ratio': 0.2, 'offset_min_tolerance': None}}
# root        : INFO     Using cuda.
# wandb: Currently logged in as: zhanh (zhanh-uwa). Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.3
# wandb: Run data is saved locally in /media/datadisk/home/22828187/zhanh/202510_hpt/wandb/run-20251019_055042-otugtlgg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Single_Velocity_HPT-extNoneNone-iter200000-lr0.0001-decayTrue10000-seed86
# wandb: ⭐️ View project at https://wandb.ai/zhanh-uwa/202510_hpt
# wandb: 🚀 View run at https://wandb.ai/zhanh-uwa/202510_hpt/runs/otugtlgg
# root        : INFO     train segments: 564137
# root        : INFO     train segments: 564137
# root        : INFO     eval test segments: 70246
# root        : INFO     eval test segments: 15857
# root        : INFO     eval test segments: 15130
# root        : INFO     Number of GPUs available: 1
# 0 tensor(0.7321, device='cuda:0', grad_fn=<DivBackward0>)
# /media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at /opt/conda/conda-bld/pytorch_1711403378171/work/torch/csrc/utils/python_arg_parser.cpp:1630.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# root        : INFO     ------------------------------------
# root        : INFO     Iteration: 0/200000
# root        : INFO         Train Loss: 0.0001
# root        : INFO         Train Stat: {'velocity_mae': 16.5676, 'velocity_std': 12.2387, 'velocity_recall': 0.4521}
# root        : INFO         Valid Maestro Stat: {'velocity_mae': 16.3641, 'velocity_std': 12.2033, 'velocity_recall': 0.4563}
# root        : INFO         Valid SMD Stat: {'velocity_mae': 16.7375, 'velocity_std': 12.6118, 'velocity_recall': 0.4558}
# root        : INFO         Valid MAPS Stat: {'velocity_mae': 18.6143, 'velocity_std': 12.8605, 'velocity_recall': 0.3885}
# root        : INFO     Train time: 8.478 s, validate time: 37.724 s
# root        : INFO     Model saved to /media/datadisk/home/22828187/zhanh/202510_hpt_data/workspaces/checkpoints/Single_Velocity_HPT/0_iteration.pth
# 1 tensor(0.7312, device='cuda:0', grad_fn=<DivBackward0>)
# 2 tensor(0.7286, device='cuda:0', grad_fn=<DivBackward0>)
# 3 tensor(0.7286, device='cuda:0', grad_fn=<DivBackward0>)
# 85 tensor(0.7229, device='cuda:0', grad_fn=<DivBackward0>)
# 86 tensor(0.7168, device='cuda:0', grad_fn=<DivBackward0>)
# 87 tensor(0.7233, device='cuda:0', grad_fn=<DivBackward0>)
# 88 tensor(0.7165, device='cuda:0', grad_fn=<DivBackward0>)
# 89 tensor(0.7152, device='cuda:0', grad_fn=<DivBackward0>)
# 90 tensor(0.7159, device='cuda:0', grad_fn=<DivBackward0>)
# 91 tensor(0.7213, device='cuda:0', grad_fn=<DivBackward0>)
# 92 tensor(0.7169, device='cuda:0', grad_fn=<DivBackward0>)
# 93 tensor(0.7136, device='cuda:0', grad_fn=<DivBackward0>)
# 94 tensor(0.7124, device='cuda:0', grad_fn=<DivBackward0>)
# 95 tensor(0.7129, device='cuda:0', grad_fn=<DivBackward0>)
# 96 tensor(0.7274, device='cuda:0', grad_fn=<DivBackward0>)
# 97 tensor(0.7111, device='cuda:0', grad_fn=<DivBackward0>)
# ^C
# Traceback (most recent call last):
#   File "/media/datadisk/home/22828187/zhanh/202510_hpt/pytorch/main_iter.py", line 276, in <module>
#     train(cfg)
#   File "/media/datadisk/home/22828187/zhanh/202510_hpt/pytorch/main_iter.py", line 167, in train
#     batch_output_dict, loss = forward_pass(cfg, model, batch_data_dict, device)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/datadisk/home/22828187/zhanh/202510_hpt/pytorch/main_iter.py", line 242, in forward_pass
#     batch_data_dict[key] = move_data_to_device(batch_data_dict[key], device)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/media/datadisk/home/22828187/zhanh/202510_hpt/pytorch/pytorch_utils.py", line 15, in move_data_to_device
#     return x.to(device)
#            ^^^^^^^^^^^^
# KeyboardInterrupt
# Exception ignored in atexit callback: <function _start_and_connect_service.<locals>.teardown_atexit at 0x7934e77e0ae0>
# Traceback (most recent call last):
#   File "/media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/wandb/sdk/lib/service_connection.py", line 93, in teardown_atexit
#     conn.teardown(hooks.exit_code)
#   File "/media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/wandb/sdk/lib/service_connection.py", line 210, in teardown
#     self._client.send(
#   File "/media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py", line 212, in send
#     self.send_server_request(server_req)
#   File "/media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py", line 154, in send_server_request
#     self._send_message(msg)
#   File "/media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py", line 151, in _send_message
#     self._sendall_with_error_handle(header + data)
#   File "/media/datadisk/home/22828187/conda_env/miniconda3/envs/hpt_mamba/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py", line 130, in _sendall_with_error_handle
#     sent = self._sock.send(data)
#            ^^^^^^^^^^^^^^^^^^^^^
# BrokenPipeError: [Errno 32] Broken pipe
